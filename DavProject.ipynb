# %%
import pandas as pd   #///D:\5th Semester\DAV\Project
birdstrikes = pd.read_csv(r'D:/5th Semester/DAV/Project/birdstrikes.csv')

# %% [markdown]
# # PreProcessing for Graph_Visualization_Data

# %%
import numpy as np
df = birdstrikes.replace(to_replace='None', value='Nan')
df = df.dropna()
# print(df.nunique())
df1=df['Aircraft Airline Operator'].value_counts()

# df1.to_csv('Graph_Visualization_Data.csv')

# %%
# df = df.dropna(subset=['Effect Amount of damage'])

# %% [markdown]
# # Scrapping Longitude and Lattitudes

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
# from webdriver_manager.firefox import ChromeDriverManage
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

# %%
Name=[]
longitude=[]
latitide=[]

# %%
options = Options()
driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
url='https://www.latlong.net/category/states-236-14.html'
driver.get(url)
for i in range(1,50):
        try:
#             print(p)
            x=driver.find_element('xpath',f'/html/body/main/table/tbody/tr[{i}]').text
#             time.sleep(10)
#             print(x)
            x=x.split()
            y=x[0]
            y=y[0:-1]
            Name.append(y)
            longitude.append(x[2])
            latitide.append(x[3])
        except:
            print("nott accesses")
# #             continue

# %%
df=pd.DataFrame({
    
"AirportName ": Name,
"longitude":longitude,
"latitide":latitide
})

# %%
df
# Out:
#             Name   longitude     latitide
# 0            Plac   Latitude    Longitude
# 1       Wisconsin  44.500000   -89.500000
# 2             Wes        USA    39.000000
# 3         Vermont  44.000000   -72.699997
# 4           Texas        USA    31.000000
# 5            Sout        the           US
# 6            Rhod        the           US
# 7          Oregon         US    44.000000
# 8              Ne        USA    43.000000
# 9              Ne        USA    44.000000
# 10       Nebraska  41.500000  -100.000000
# 11         Kansas         US    38.500000
# 12    Mississippi  33.000000   -90.000000
# 13       Illinois  40.000000   -89.000000
# 14       Delaware         US    39.000000
# 15    Connecticut  41.599998   -72.699997
# 16       Arkansas         US    34.799999
# 17        Indiana  40.273502   -86.126976
# 18       Missouri  38.573936   -92.603760
# 19        Florida  27.994402   -81.760254
# 20         Nevada  39.876019  -117.224121
# ...

# %%
df.to_csv('hierarchy.csv')
